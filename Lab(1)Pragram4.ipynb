# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator
from qiskit.quantum_info import *
from qiskit.visualization import plot_state_city
# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-10-27 05:20:37,041: Credentials are already in use. The existing account in the session will be replaced.

# %%
qc = QuantumCircuit(2)
# swaps states of qubits a and b
qc.swap(0,1)
qc.draw()




#plot_state_city(rho_AB.data, title='Density Matrix')

# %%
rho_AB = DensityMatrix.from_instruction(qc)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
Statevector(qc).draw('city')

# %%
qc = QuantumCircuit(2)
# swaps states of qubits a and b
qc.cx(a,b)
qc.cx(b,a)
qc.cx(a,b)
qc.draw()

# %%
rho_AB = DensityMatrix.from_instruction(qc)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
Statevector(qc).draw('city')
