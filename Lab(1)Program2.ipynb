# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ,execute
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-10-26 16:58:30,993: Credentials are already in use. The existing account in the session will be replaced.

# %%
qc=QuantumCircuit(2,2)

qc.cx(0,1)
qc.h(1)
qc.cx(1,0)

qc.draw()

# %%
from qiskit.quantum_info import Statevector
state=Statevector.from_int(1,4)
state=state.evolve(qc)
state.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |01\rangle- \frac{\sqrt{2}}{2} |10\rangle$$

# %%
rho_AB = qi.DensityMatrix.from_instruction(qc)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
# Out:
# $$
# \rho_{AB} =
# \begin{bmatrix}
# \tfrac{1}{2} & 0 & 0 & \tfrac{1}{2}  \\
#  0 & 0 & 0 & 0  \\
#  0 & 0 & 0 & 0  \\
#  \tfrac{1}{2} & 0 & 0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import plot_state_city
plot_state_city(rho_AB.data, title='Density Matrix')
